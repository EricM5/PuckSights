# %%
import requests
import pandas as pd
from datetime import date


BASE_URL = "https://statsapi.web.nhl.com"

#more API info: https://gitlab.com/dword4/nhlapi/-/blob/master/stats-api.md#people

pd.set_option("display.max_rows", None)

response = requests.get("https://statsapi.web.nhl.com/api/v1/teams?expand=team.roster")

df = pd.json_normalize(response.json())


response.json()

c = pd.json_normalize(response.json(), record_path=["teams"])[["roster.roster"]].apply(pd.Series)

playerdf = pd.json_normalize(c.loc[25][0]).set_index("person.fullName")

personidseries = playerdf["person.id"]

player_id_df = pd.DataFrame()
df = c.reset_index()  # make sure indexes pair with number of rows

for index, row in df.iterrows():
    player_id_df = pd.concat([player_id_df, pd.json_normalize(c.loc[index][0]).set_index("person.fullName")])
#player_id_df is a df with index person.fullName 

player_id_df
# list(player_id_df.index)

["hello"].to_json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vf/sz09m23d7jg_pgsjtvqvdbcc0000gn/T/ipykernel_15616/3654520102.py in <module>
#      33 # list(player_id_df.index)
#      34
# ---> 35 ["hello"].to_json()
#
# AttributeError: 'list' object has no attribute 'to_json'

# %%
#list of player names
player_names_list = list(player_id_df.index)

# %%
#Player must be in the df
def getPlayerId(name):
    player_id = player_id_df.loc[name]["person.id"]
    return player_id

print(getPlayerId("Logan Couture"))
# Out:
# 8474053

# %%
def get_general_stats(player_name):
    player_id = getPlayerId(player_name)
    '''
    returns df of previous stats, year to year
    and list of teams played for
    '''
    response = requests.get(BASE_URL + f"/api/v1/people/{player_id}/stats?stats=yearByYear")
    response_json = response.json()["stats"][0]["splits"]
    df = pd.json_normalize(response_json)
    teams_list = [f"{df.iloc[i]['team.name']} ({df.iloc[i]['league.name']})" for i in range(len(list(df['team.name'])) - 1, -1, -1)]
#     teams_played_for = set(df["team.name"])
    seen = set()
    teams_played_for = [x for x in teams_list if not (x in seen or seen.add(x))]
#     teams_played_for = set(teams_list)
    return df, teams_played_for

def get_stats_for_team(player_name, team, stats_df):
    df = stats_df.set_index("team.name") #where stats_df is entire player season(s) history stats
    df_team_specific = df.loc[[team]].set_index("season")
    season_list = list(df_team_specific.index)
    goal_list = list(df_team_specific["stat.goals"])
    assist_list = list(df_team_specific["stat.assists"])
    points_list = list(df_team_specific["stat.points"])
    return season_list, goal_list, assist_list, points_list, df_team_specific


player_name = "Logan Couture"

general_stats_df, teams_played_for = get_general_stats(player_name)

print(teams_played_for)
#use "teams_played_for" for drop down select
# desired_team = "Seattle Kraken"

# year_list, goal_list, assist_list, points_list, df_team_specific = get_stats_for_team(player_name, desired_team, general_stats_df)

# print(f"Year List", year_list)
# print(f"Goal List", goal_list)
# print(f"Assist List", assist_list)
# print(f"Points List", points_list)
general_stats_df
# Out:
# ['San Jose Sharks (National Hockey League)', 'Canada (WCup)', 'Geneve (Swiss)', 'Worcester (AHL)', 'Ottawa (OHL)', 'Canada (WJ18-A)', 'St. Thomas (OJHL-B)', 'London Jr. Knights Bantam AAA (MHAO)']
#       season  sequenceNumber  stat.assists  stat.goals  stat.pim  stat.games  \
# 0   20032004        10148519            56          51      42.0          56
# 1   20042005               1            22          24       NaN          48
# 2   20052006               1            39          25      52.0          65
# 3   20062007               1            52          26      24.0          54
# 4   20062007               3             2           2       2.0           6
# 5   20072008               1            37          21      37.0          51
# 6   20082009               1            48          39      46.0          62
# 7   20082009               2             0           0       7.0           4
# 8   20092010               1             4           5       6.0          25
# 9   20092010               2            33          20      12.0          42
# 10  20102011               1            24          32      41.0          79
# 11  20112012               1            34          31      16.0          80
# 12  20122013               1            16          21       4.0          48
# 13  20122013               2            16           7      10.0          22
# 14  20132014               1            31          23      20.0          65
# 15  20142015               1            40          27      12.0          82
# 16  20152016               1            21          15      20.0          52
# 17  20162017               1            27          25      12.0          73
# 18  20162017           17216             3           1       0.0           6
# 19  20172018               1            27          34      18.0          78
# 20  20182019               1            43          27      22.0          81
# 21  20192020               1            23          16      18.0          52
# 22  20202021               1            14          17      25.0          53
# 23  20212022               1            33          23      18.0          77
#
#    stat.penaltyMinutes  stat.plusMinus  stat.points  \
# 0                   42             0.0          107
# 1                  NaN             NaN           46
# 2                   52            -4.0           64
# 3                   24            -1.0           78
# 4                    2             NaN            4
# 5                   37             9.0           58
# 6                   46            27.0           87
# 7                    7            -1.0            0
# 8                    6             4.0            9
# 9                   12            16.0           53
# 10                  41            18.0           56
# 11                  16             2.0           65
# 12                   4             7.0           37
# 13                  10             NaN           23
# 14                  20            21.0           54
# 15                  12            -6.0           67
# 16                  20             2.0           36
# 17                  12            11.0           52
# 18                   0             3.0            4
# 19                  18            -2.0           61
# 20                  22            -6.0           70
# 21                  18             0.0           39
# 22                  25           -11.0           31
# 23                  18           -11.0           56
#
#                         team.name  ... stat.shortHandedTimeOnIce stat.shifts  \
# 0   London Jr. Knights Bantam AAA  ...                       NaN         NaN
# 1                      St. Thomas  ...                       NaN         NaN
# 2                          Ottawa  ...                       NaN         NaN
# 3                          Ottawa  ...                       NaN         NaN
# 4                          Canada  ...                     00:00         0.0
# 5                          Ottawa  ...                       NaN         NaN
# 6                          Ottawa  ...                       NaN         NaN
# 7                       Worcester  ...                       NaN         NaN
# 8                 San Jose Sharks  ...                     00:17       383.0
# 9                       Worcester  ...                       NaN         NaN
# 10                San Jose Sharks  ...                     85:17      1923.0
# 11                San Jose Sharks  ...                     87:52      2022.0
# 12                San Jose Sharks  ...                     42:55      1179.0
# 13                         Geneve  ...                       NaN         NaN
# 14                San Jose Sharks  ...                     88:26      1733.0
# 15                San Jose Sharks  ...                    119:50      2122.0
# 16                San Jose Sharks  ...                     38:56      1198.0
# 17                San Jose Sharks  ...                     80:09      1780.0
# 18                         Canada  ...                       NaN         NaN
# 19                San Jose Sharks  ...                    109:06      1955.0
# 20                San Jose Sharks  ...                    126:29      1970.0
# 21                San Jose Sharks  ...                     87:56      1219.0
# 22                San Jose Sharks  ...                    103:08      1327.0
# 23                San Jose Sharks  ...                    146:38      2023.0
#
#    stat.gameWinningGoals  stat.shots  stat.hits  stat.powerPlayPoints  \
# 0                    NaN         NaN        NaN                   NaN
# 1                    NaN         NaN        NaN                   NaN
# 2                    NaN         NaN        NaN                   NaN
# 3                    NaN         NaN        NaN                   NaN
# 4                    NaN         NaN        NaN                   NaN
# 5                    NaN         NaN        NaN                   NaN
# 6                    NaN         NaN        NaN                   NaN
# 7                    0.0         NaN        NaN                   NaN
# 8                    1.0        42.0       14.0                   1.0
# 9                    9.0         NaN        NaN                   NaN
# 10                   8.0       253.0       60.0                  14.0
# 11                   5.0       245.0       42.0                  26.0
# 12                   5.0       151.0       32.0                  12.0
# 13                   NaN         NaN        NaN                   NaN
# 14                   6.0       233.0       16.0                  13.0
# 15                   4.0       263.0       85.0                  24.0
# 16                   4.0       137.0       29.0                  15.0
# 17                   3.0       174.0       57.0                  15.0
# 18                   NaN         NaN        NaN                   NaN
# 19                   4.0       204.0       33.0                  21.0
# 20                   3.0       204.0       65.0                  18.0
# 21                   3.0       126.0       54.0                   9.0
# 22                   2.0       114.0       58.0                   6.0
# 23                   3.0       199.0       92.0                  17.0
#
#     stat.shotPct stat.overTimeGoals stat.shortHandedPoints stat.blocked
# 0            NaN                NaN                    NaN          NaN
# 1            NaN                NaN                    NaN          NaN
# 2            NaN                NaN                    NaN          NaN
# 3            NaN                NaN                    NaN          NaN
# 4            NaN                NaN                    NaN          NaN
# 5            NaN                NaN                    NaN          NaN
# 6            NaN                NaN                    NaN          NaN
# 7            NaN                NaN                    NaN          NaN
# 8          11.90                0.0                    0.0         11.0
# 9            NaN                NaN                    NaN          NaN
# 10         12.65                1.0                    0.0         66.0
# 11         12.65                0.0                    2.0         76.0
# 12         13.91                0.0                    1.0         51.0
# 13           NaN                NaN                    NaN          NaN
# 14          9.87                0.0                    4.0         68.0
# 15         10.27                0.0                    2.0         71.0
# 16         10.95                0.0                    0.0         38.0
# 17         14.37                0.0                    1.0         65.0
# 18           NaN                NaN                    NaN          NaN
# 19         16.67                1.0                    3.0         72.0
# 20         13.24                0.0                    2.0         52.0
# 21         12.70                3.0                    2.0         45.0
# 22         14.90                0.0                    1.0         39.0
# 23         11.60                1.0                    3.0         58.0
#
# [24 rows x 31 columns]

# %%
def getStandingsByYear(year=f"{date.today().year - 1}{date.today().year}"):
    '''
    returns standings based on year
    default is the current year
    '''
    print(f"{date.today().year - 1}{date.today().year}")
    
    
    response = requests.get(BASE_URL + f"/api/v1/standings?season={year}")
    return response.json()

getStandingsByYear("20062007")
# Out:
# 20212022
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2022. All Rights Reserved.',
#  'records': [{'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 1, 'name': 'Atlantic', 'link': '/api/v1/divisions/1'},
#    'conference': {'id': 1, 'name': 'Eastern', 'link': '/api/v1/conferences/1'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 1,
#       'name': 'New Jersey Devils',
#       'link': '/api/v1/teams/1'},
#      'leagueRecord': {'wins': 49, 'losses': 24, 'ot': 9, 'type': 'league'},
#      'goalsAgainst': 201,
#      'goalsScored': 216,
#      'points': 107,
#      'divisionRank': '1',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '2',
#      'conferenceRank': '2',
#      'conferenceL10Rank': '7',
#      'conferenceRoadRank': '2',
#      'conferenceHomeRank': '4',
#      'leagueRank': '7',
#      'leagueL10Rank': '12',
#      'leagueRoadRank': '4',
#      'leagueHomeRank': '10',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.6524390243902439,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '2',
#      'ppLeagueRank': '6',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 5,
#       'name': 'Pittsburgh Penguins',
#       'link': '/api/v1/teams/5'},
#      'leagueRecord': {'wins': 47, 'losses': 24, 'ot': 11, 'type': 'league'},
#      'goalsAgainst': 246,
#      'goalsScored': 277,
#      'points': 105,
#      'divisionRank': '2',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '5',
#      'conferenceL10Rank': '6',
#      'conferenceRoadRank': '5',
#      'conferenceHomeRank': '2',
#      'leagueRank': '10',
#      'leagueL10Rank': '11',
#      'leagueRoadRank': '11',
#      'leagueHomeRank': '8',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6402439024390244,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '4',
#      'ppLeagueRank': '10',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 3, 'name': 'New York Rangers', 'link': '/api/v1/teams/3'},
#      'leagueRecord': {'wins': 42, 'losses': 30, 'ot': 10, 'type': 'league'},
#      'goalsAgainst': 216,
#      'goalsScored': 242,
#      'points': 94,
#      'divisionRank': '3',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '4',
#      'conferenceRank': '6',
#      'conferenceL10Rank': '1',
#      'conferenceRoadRank': '6',
#      'conferenceHomeRank': '10',
#      'leagueRank': '15',
#      'leagueL10Rank': '4',
#      'leagueRoadRank': '12',
#      'leagueHomeRank': '19',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.573170731707317,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '6',
#      'ppLeagueRank': '15',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 2,
#       'name': 'New York Islanders',
#       'link': '/api/v1/teams/2'},
#      'leagueRecord': {'wins': 40, 'losses': 30, 'ot': 12, 'type': 'league'},
#      'goalsAgainst': 240,
#      'goalsScored': 248,
#      'points': 92,
#      'divisionRank': '4',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '3',
#      'conferenceRank': '8',
#      'conferenceL10Rank': '8',
#      'conferenceRoadRank': '10',
#      'conferenceHomeRank': '8',
#      'leagueRank': '17',
#      'leagueL10Rank': '13',
#      'leagueRoadRank': '17',
#      'leagueHomeRank': '16',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 4, 'streakCode': 'W4'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5609756097560976,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '8',
#      'ppLeagueRank': '17',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 4,
#       'name': 'Philadelphia Flyers',
#       'link': '/api/v1/teams/4'},
#      'leagueRecord': {'wins': 22, 'losses': 48, 'ot': 12, 'type': 'league'},
#      'goalsAgainst': 303,
#      'goalsScored': 214,
#      'points': 56,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '15',
#      'conferenceL10Rank': '14',
#      'conferenceRoadRank': '14',
#      'conferenceHomeRank': '15',
#      'leagueRank': '30',
#      'leagueL10Rank': '28',
#      'leagueRoadRank': '27',
#      'leagueHomeRank': '30',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.34146341463414637,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '15',
#      'ppLeagueRank': '30',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 2, 'name': 'Northeast', 'link': '/api/v1/divisions/2'},
#    'conference': {'id': 1, 'name': 'Eastern', 'link': '/api/v1/conferences/1'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 7,
#       'name': 'Buffalo Sabres',
#       'link': '/api/v1/teams/7'},
#      'leagueRecord': {'wins': 53, 'losses': 22, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 242,
#      'goalsScored': 308,
#      'points': 113,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '1',
#      'conferenceRank': '1',
#      'conferenceL10Rank': '2',
#      'conferenceRoadRank': '1',
#      'conferenceHomeRank': '1',
#      'leagueRank': '1',
#      'leagueL10Rank': '6',
#      'leagueRoadRank': '1',
#      'leagueHomeRank': '6',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'p',
#      'pointsPercentage': 0.6890243902439024,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '1',
#      'ppLeagueRank': '2',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 9, 'name': 'Ottawa Senators', 'link': '/api/v1/teams/9'},
#      'leagueRecord': {'wins': 48, 'losses': 25, 'ot': 9, 'type': 'league'},
#      'goalsAgainst': 222,
#      'goalsScored': 288,
#      'points': 105,
#      'divisionRank': '2',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '3',
#      'conferenceRank': '4',
#      'conferenceL10Rank': '5',
#      'conferenceRoadRank': '4',
#      'conferenceHomeRank': '6',
#      'leagueRank': '9',
#      'leagueL10Rank': '8',
#      'leagueRoadRank': '3',
#      'leagueHomeRank': '13',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6402439024390244,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '3',
#      'ppLeagueRank': '8',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 10,
#       'name': 'Toronto Maple Leafs',
#       'link': '/api/v1/teams/10'},
#      'leagueRecord': {'wins': 40, 'losses': 31, 'ot': 11, 'type': 'league'},
#      'goalsAgainst': 269,
#      'goalsScored': 258,
#      'points': 91,
#      'divisionRank': '3',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '4',
#      'conferenceRank': '9',
#      'conferenceL10Rank': '9',
#      'conferenceRoadRank': '8',
#      'conferenceHomeRank': '9',
#      'leagueRank': '18',
#      'leagueL10Rank': '14',
#      'leagueRoadRank': '15',
#      'leagueHomeRank': '18',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5548780487804879,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '9',
#      'ppLeagueRank': '18',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 8,
#       'name': 'Montréal Canadiens',
#       'link': '/api/v1/teams/8'},
#      'leagueRecord': {'wins': 42, 'losses': 34, 'ot': 6, 'type': 'league'},
#      'goalsAgainst': 256,
#      'goalsScored': 245,
#      'points': 90,
#      'divisionRank': '4',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '2',
#      'conferenceRank': '10',
#      'conferenceL10Rank': '4',
#      'conferenceRoadRank': '12',
#      'conferenceHomeRank': '5',
#      'leagueRank': '19',
#      'leagueL10Rank': '7',
#      'leagueRoadRank': '21',
#      'leagueHomeRank': '11',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.5487804878048781,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '10',
#      'ppLeagueRank': '19',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 6, 'name': 'Boston Bruins', 'link': '/api/v1/teams/6'},
#      'leagueRecord': {'wins': 35, 'losses': 41, 'ot': 6, 'type': 'league'},
#      'goalsAgainst': 289,
#      'goalsScored': 219,
#      'points': 76,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '5',
#      'conferenceRank': '13',
#      'conferenceL10Rank': '15',
#      'conferenceRoadRank': '11',
#      'conferenceHomeRank': '14',
#      'leagueRank': '23',
#      'leagueL10Rank': '30',
#      'leagueRoadRank': '20',
#      'leagueHomeRank': '26',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 6, 'streakCode': 'L6'},
#      'pointsPercentage': 0.4634146341463415,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '13',
#      'ppLeagueRank': '23',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 3, 'name': 'Southeast', 'link': '/api/v1/divisions/3'},
#    'conference': {'id': 1, 'name': 'Eastern', 'link': '/api/v1/conferences/1'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 11,
#       'name': 'Atlanta Thrashers',
#       'link': '/api/v1/teams/11'},
#      'leagueRecord': {'wins': 43, 'losses': 28, 'ot': 11, 'type': 'league'},
#      'goalsAgainst': 245,
#      'goalsScored': 246,
#      'points': 97,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '3',
#      'conferenceL10Rank': '3',
#      'conferenceRoadRank': '7',
#      'conferenceHomeRank': '3',
#      'leagueRank': '12',
#      'leagueL10Rank': '15',
#      'leagueRoadRank': '14',
#      'leagueHomeRank': '14',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.5914634146341463,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '5',
#      'ppLeagueRank': '12',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 14,
#       'name': 'Tampa Bay Lightning',
#       'link': '/api/v1/teams/14'},
#      'leagueRecord': {'wins': 44, 'losses': 33, 'ot': 5, 'type': 'league'},
#      'goalsAgainst': 261,
#      'goalsScored': 253,
#      'points': 93,
#      'divisionRank': '2',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '4',
#      'conferenceRank': '7',
#      'conferenceL10Rank': '11',
#      'conferenceRoadRank': '3',
#      'conferenceHomeRank': '12',
#      'leagueRank': '16',
#      'leagueL10Rank': '20',
#      'leagueRoadRank': '10',
#      'leagueHomeRank': '21',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5670731707317073,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '7',
#      'ppLeagueRank': '16',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 12,
#       'name': 'Carolina Hurricanes',
#       'link': '/api/v1/teams/12'},
#      'leagueRecord': {'wins': 40, 'losses': 34, 'ot': 8, 'type': 'league'},
#      'goalsAgainst': 253,
#      'goalsScored': 241,
#      'points': 88,
#      'divisionRank': '3',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '3',
#      'conferenceRank': '11',
#      'conferenceL10Rank': '12',
#      'conferenceRoadRank': '9',
#      'conferenceHomeRank': '11',
#      'leagueRank': '20',
#      'leagueL10Rank': '22',
#      'leagueRoadRank': '16',
#      'leagueHomeRank': '20',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5365853658536586,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '11',
#      'ppLeagueRank': '20',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 13,
#       'name': 'Florida Panthers',
#       'link': '/api/v1/teams/13'},
#      'leagueRecord': {'wins': 35, 'losses': 31, 'ot': 16, 'type': 'league'},
#      'goalsAgainst': 257,
#      'goalsScored': 247,
#      'points': 86,
#      'divisionRank': '4',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '2',
#      'conferenceRank': '12',
#      'conferenceL10Rank': '10',
#      'conferenceRoadRank': '13',
#      'conferenceHomeRank': '7',
#      'leagueRank': '21',
#      'leagueL10Rank': '16',
#      'leagueRoadRank': '23',
#      'leagueHomeRank': '15',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'pointsPercentage': 0.524390243902439,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '12',
#      'ppLeagueRank': '21',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 15,
#       'name': 'Washington Capitals',
#       'link': '/api/v1/teams/15'},
#      'leagueRecord': {'wins': 28, 'losses': 40, 'ot': 14, 'type': 'league'},
#      'goalsAgainst': 286,
#      'goalsScored': 235,
#      'points': 70,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '14',
#      'conferenceL10Rank': '13',
#      'conferenceRoadRank': '15',
#      'conferenceHomeRank': '13',
#      'leagueRank': '27',
#      'leagueL10Rank': '25',
#      'leagueRoadRank': '28',
#      'leagueHomeRank': '23',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'pointsPercentage': 0.4268292682926829,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '14',
#      'ppLeagueRank': '27',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 4, 'name': 'Central', 'link': '/api/v1/divisions/4'},
#    'conference': {'id': 2, 'name': 'Western', 'link': '/api/v1/conferences/2'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 17,
#       'name': 'Detroit Red Wings',
#       'link': '/api/v1/teams/17'},
#      'leagueRecord': {'wins': 50, 'losses': 19, 'ot': 13, 'type': 'league'},
#      'goalsAgainst': 199,
#      'goalsScored': 254,
#      'points': 113,
#      'divisionRank': '1',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '1',
#      'conferenceL10Rank': '3',
#      'conferenceRoadRank': '7',
#      'conferenceHomeRank': '1',
#      'leagueRank': '2',
#      'leagueL10Rank': '9',
#      'leagueRoadRank': '13',
#      'leagueHomeRank': '1',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'clinchIndicator': 'z',
#      'pointsPercentage': 0.6890243902439024,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '1',
#      'ppLeagueRank': '1',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 18,
#       'name': 'Nashville Predators',
#       'link': '/api/v1/teams/18'},
#      'leagueRecord': {'wins': 51, 'losses': 23, 'ot': 8, 'type': 'league'},
#      'goalsAgainst': 212,
#      'goalsScored': 272,
#      'points': 110,
#      'divisionRank': '2',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '2',
#      'conferenceRank': '4',
#      'conferenceL10Rank': '8',
#      'conferenceRoadRank': '2',
#      'conferenceHomeRank': '5',
#      'leagueRank': '3',
#      'leagueL10Rank': '18',
#      'leagueRoadRank': '5',
#      'leagueHomeRank': '4',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6707317073170732,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '2',
#      'ppLeagueRank': '3',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 19, 'name': 'St. Louis Blues', 'link': '/api/v1/teams/19'},
#      'leagueRecord': {'wins': 34, 'losses': 35, 'ot': 13, 'type': 'league'},
#      'goalsAgainst': 254,
#      'goalsScored': 214,
#      'points': 81,
#      'divisionRank': '3',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '4',
#      'conferenceRank': '10',
#      'conferenceL10Rank': '11',
#      'conferenceRoadRank': '9',
#      'conferenceHomeRank': '13',
#      'leagueRank': '22',
#      'leagueL10Rank': '23',
#      'leagueRoadRank': '19',
#      'leagueHomeRank': '27',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.49390243902439024,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '10',
#      'ppLeagueRank': '22',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 29,
#       'name': 'Columbus Blue Jackets',
#       'link': '/api/v1/teams/29'},
#      'leagueRecord': {'wins': 33, 'losses': 42, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 249,
#      'goalsScored': 201,
#      'points': 73,
#      'divisionRank': '4',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '3',
#      'conferenceRank': '11',
#      'conferenceL10Rank': '10',
#      'conferenceRoadRank': '11',
#      'conferenceHomeRank': '12',
#      'leagueRank': '24',
#      'leagueL10Rank': '21',
#      'leagueRoadRank': '24',
#      'leagueHomeRank': '25',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'pointsPercentage': 0.4451219512195122,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '11',
#      'ppLeagueRank': '24',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 16,
#       'name': 'Chicago Blackhawks',
#       'link': '/api/v1/teams/16'},
#      'leagueRecord': {'wins': 31, 'losses': 42, 'ot': 9, 'type': 'league'},
#      'goalsAgainst': 258,
#      'goalsScored': 201,
#      'points': 71,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '13',
#      'conferenceL10Rank': '12',
#      'conferenceRoadRank': '12',
#      'conferenceHomeRank': '15',
#      'leagueRank': '26',
#      'leagueL10Rank': '24',
#      'leagueRoadRank': '25',
#      'leagueHomeRank': '29',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 2, 'streakCode': 'L2'},
#      'pointsPercentage': 0.4329268292682927,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '13',
#      'ppLeagueRank': '26',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 5, 'name': 'Northwest', 'link': '/api/v1/divisions/5'},
#    'conference': {'id': 2, 'name': 'Western', 'link': '/api/v1/conferences/2'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 23,
#       'name': 'Vancouver Canucks',
#       'link': '/api/v1/teams/23'},
#      'leagueRecord': {'wins': 49, 'losses': 26, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 201,
#      'goalsScored': 222,
#      'points': 105,
#      'divisionRank': '1',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '3',
#      'conferenceRank': '3',
#      'conferenceL10Rank': '6',
#      'conferenceRoadRank': '3',
#      'conferenceHomeRank': '7',
#      'leagueRank': '8',
#      'leagueL10Rank': '10',
#      'leagueRoadRank': '6',
#      'leagueHomeRank': '9',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 1, 'streakCode': 'L1'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.6402439024390244,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '6',
#      'ppLeagueRank': '9',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 30, 'name': 'Minnesota Wild', 'link': '/api/v1/teams/30'},
#      'leagueRecord': {'wins': 48, 'losses': 26, 'ot': 8, 'type': 'league'},
#      'goalsAgainst': 191,
#      'goalsScored': 235,
#      'points': 104,
#      'divisionRank': '2',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '1',
#      'conferenceRank': '7',
#      'conferenceL10Rank': '2',
#      'conferenceRoadRank': '8',
#      'conferenceHomeRank': '2',
#      'leagueRank': '11',
#      'leagueL10Rank': '3',
#      'leagueRoadRank': '18',
#      'leagueHomeRank': '2',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 3, 'streakCode': 'W3'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6341463414634146,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '7',
#      'ppLeagueRank': '11',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 20, 'name': 'Calgary Flames', 'link': '/api/v1/teams/20'},
#      'leagueRecord': {'wins': 43, 'losses': 29, 'ot': 10, 'type': 'league'},
#      'goalsAgainst': 226,
#      'goalsScored': 258,
#      'points': 96,
#      'divisionRank': '3',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '2',
#      'conferenceRank': '8',
#      'conferenceL10Rank': '7',
#      'conferenceRoadRank': '10',
#      'conferenceHomeRank': '4',
#      'leagueRank': '13',
#      'leagueL10Rank': '17',
#      'leagueRoadRank': '22',
#      'leagueHomeRank': '3',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'losses', 'streakNumber': 4, 'streakCode': 'L4'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.5853658536585366,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '8',
#      'ppLeagueRank': '13',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 21,
#       'name': 'Colorado Avalanche',
#       'link': '/api/v1/teams/21'},
#      'leagueRecord': {'wins': 44, 'losses': 31, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 251,
#      'goalsScored': 272,
#      'points': 95,
#      'divisionRank': '4',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '4',
#      'conferenceRank': '9',
#      'conferenceL10Rank': '5',
#      'conferenceRoadRank': '6',
#      'conferenceHomeRank': '9',
#      'leagueRank': '14',
#      'leagueL10Rank': '5',
#      'leagueRoadRank': '9',
#      'leagueHomeRank': '17',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.5792682926829268,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '9',
#      'ppLeagueRank': '14',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 22, 'name': 'Edmonton Oilers', 'link': '/api/v1/teams/22'},
#      'leagueRecord': {'wins': 32, 'losses': 43, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 248,
#      'goalsScored': 195,
#      'points': 71,
#      'divisionRank': '5',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '5',
#      'conferenceRank': '12',
#      'conferenceL10Rank': '15',
#      'conferenceRoadRank': '13',
#      'conferenceHomeRank': '10',
#      'leagueRank': '25',
#      'leagueL10Rank': '29',
#      'leagueRoadRank': '26',
#      'leagueHomeRank': '22',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.4329268292682927,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '12',
#      'ppLeagueRank': '25',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]},
#   {'standingsType': 'regularSeason',
#    'league': {'id': 133,
#     'name': 'National Hockey League',
#     'link': '/api/v1/league/133'},
#    'division': {'id': 6, 'name': 'Pacific', 'link': '/api/v1/divisions/6'},
#    'conference': {'id': 2, 'name': 'Western', 'link': '/api/v1/conferences/2'},
#    'season': '20062007',
#    'teamRecords': [{'team': {'id': 24,
#       'name': 'Anaheim Ducks',
#       'link': '/api/v1/teams/24'},
#      'leagueRecord': {'wins': 48, 'losses': 20, 'ot': 14, 'type': 'league'},
#      'goalsAgainst': 208,
#      'goalsScored': 258,
#      'points': 110,
#      'divisionRank': '1',
#      'divisionL10Rank': '3',
#      'divisionRoadRank': '2',
#      'divisionHomeRank': '1',
#      'conferenceRank': '2',
#      'conferenceL10Rank': '9',
#      'conferenceRoadRank': '4',
#      'conferenceHomeRank': '3',
#      'leagueRank': '4',
#      'leagueL10Rank': '19',
#      'leagueRoadRank': '7',
#      'leagueHomeRank': '5',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'clinchIndicator': 'y',
#      'pointsPercentage': 0.6707317073170732,
#      'ppDivisionRank': '1',
#      'ppConferenceRank': '3',
#      'ppLeagueRank': '4',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 28, 'name': 'San Jose Sharks', 'link': '/api/v1/teams/28'},
#      'leagueRecord': {'wins': 51, 'losses': 26, 'ot': 5, 'type': 'league'},
#      'goalsAgainst': 199,
#      'goalsScored': 258,
#      'points': 107,
#      'divisionRank': '2',
#      'divisionL10Rank': '1',
#      'divisionRoadRank': '1',
#      'divisionHomeRank': '3',
#      'conferenceRank': '5',
#      'conferenceL10Rank': '1',
#      'conferenceRoadRank': '1',
#      'conferenceHomeRank': '8',
#      'leagueRank': '5',
#      'leagueL10Rank': '1',
#      'leagueRoadRank': '2',
#      'leagueHomeRank': '12',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'ot', 'streakNumber': 1, 'streakCode': 'OT1'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6524390243902439,
#      'ppDivisionRank': '2',
#      'ppConferenceRank': '4',
#      'ppLeagueRank': '5',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 25, 'name': 'Dallas Stars', 'link': '/api/v1/teams/25'},
#      'leagueRecord': {'wins': 50, 'losses': 25, 'ot': 7, 'type': 'league'},
#      'goalsAgainst': 197,
#      'goalsScored': 226,
#      'points': 107,
#      'divisionRank': '3',
#      'divisionL10Rank': '2',
#      'divisionRoadRank': '3',
#      'divisionHomeRank': '2',
#      'conferenceRank': '6',
#      'conferenceL10Rank': '4',
#      'conferenceRoadRank': '5',
#      'conferenceHomeRank': '6',
#      'leagueRank': '6',
#      'leagueL10Rank': '2',
#      'leagueRoadRank': '8',
#      'leagueHomeRank': '7',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 2, 'streakCode': 'W2'},
#      'clinchIndicator': 'x',
#      'pointsPercentage': 0.6524390243902439,
#      'ppDivisionRank': '3',
#      'ppConferenceRank': '5',
#      'ppLeagueRank': '7',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 26,
#       'name': 'Los Angeles Kings',
#       'link': '/api/v1/teams/26'},
#      'leagueRecord': {'wins': 27, 'losses': 41, 'ot': 14, 'type': 'league'},
#      'goalsAgainst': 283,
#      'goalsScored': 227,
#      'points': 68,
#      'divisionRank': '4',
#      'divisionL10Rank': '5',
#      'divisionRoadRank': '5',
#      'divisionHomeRank': '4',
#      'conferenceRank': '14',
#      'conferenceL10Rank': '14',
#      'conferenceRoadRank': '15',
#      'conferenceHomeRank': '11',
#      'leagueRank': '28',
#      'leagueL10Rank': '27',
#      'leagueRoadRank': '30',
#      'leagueHomeRank': '24',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.4146341463414634,
#      'ppDivisionRank': '4',
#      'ppConferenceRank': '14',
#      'ppLeagueRank': '28',
#      'lastUpdated': '2022-06-27T14:40:39Z'},
#     {'team': {'id': 27, 'name': 'Phoenix Coyotes', 'link': '/api/v1/teams/27'},
#      'leagueRecord': {'wins': 31, 'losses': 46, 'ot': 5, 'type': 'league'},
#      'goalsAgainst': 284,
#      'goalsScored': 216,
#      'points': 67,
#      'divisionRank': '5',
#      'divisionL10Rank': '4',
#      'divisionRoadRank': '4',
#      'divisionHomeRank': '5',
#      'conferenceRank': '15',
#      'conferenceL10Rank': '13',
#      'conferenceRoadRank': '14',
#      'conferenceHomeRank': '14',
#      'leagueRank': '29',
#      'leagueL10Rank': '26',
#      'leagueRoadRank': '29',
#      'leagueHomeRank': '28',
#      'wildCardRank': '0',
#      'gamesPlayed': 82,
#      'streak': {'streakType': 'wins', 'streakNumber': 1, 'streakCode': 'W1'},
#      'pointsPercentage': 0.40853658536585363,
#      'ppDivisionRank': '5',
#      'ppConferenceRank': '15',
#      'ppLeagueRank': '29',
#      'lastUpdated': '2022-06-27T14:40:39Z'}]}]}
